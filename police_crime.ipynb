# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("police_department_data.csv")

# %%
df
# Out:
#         incident_id        category  \
# 0         120058272     WEAPON LAWS
# 1         120058272     WEAPON LAWS
# 2         141059263        WARRANTS
# 3         160013662    NON-CRIMINAL
# 4         160002740    NON-CRIMINAL
# ...             ...             ...
# 150495    161061000         ASSAULT
# 150496    176000742    NON-CRIMINAL
# 150497    176000758   LARCENY/THEFT
# 150498    176000764   LARCENY/THEFT
# 150499    179002868  OTHER OFFENSES
#
#                                         crime_description  \
# 0                               POSS OF PROHIBITED WEAPON
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2                                          WARRANT ARREST
# 3                                           LOST PROPERTY
# 4                                           LOST PROPERTY
# ...                                                   ...
# 150495                                            BATTERY
# 150496                                      LOST PROPERTY
# 150497                            PETTY THEFT OF PROPERTY
# 150498                            GRAND THEFT OF PROPERTY
# 150499  FRAUDULENT GAME OR TRICK, OBTAINING MONEY OR P...
#
#                  crime_date department_district      resolution  \
# 0       2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1       2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2       2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3       2016-01-05 23:50:00          TENDERLOIN            NONE
# 4       2016-01-01 00:30:00             MISSION            NONE
# ...                     ...                 ...             ...
# 150495  2016-12-30 21:01:00                PARK            NONE
# 150496  2016-12-30 08:00:00             CENTRAL            NONE
# 150497  2016-12-29 20:00:00             CENTRAL            NONE
# 150498  2016-12-30 10:00:00             CENTRAL            NONE
# 150499  2016-12-02 14:00:00            SOUTHERN            NONE
#
#                          address   department_id  \
# 0         800 Block of BRYANT ST  12005827212120
# 1         800 Block of BRYANT ST  12005827212168
# 2          KEITH ST / SHAFTER AV  14105926363010
# 3         JONES ST / OFARRELL ST  16001366271000
# 4           16TH ST / MISSION ST  16000274071000
# ...                          ...             ...
# 150495       OAK ST / STANYAN ST  16106100004134
# 150496   JACKSON ST / SANSOME ST  17600074271000
# 150497       PINE ST / TAYLOR ST  17600075806372
# 150498  200 Block of STOCKTON ST  17600076406374
# 150499    800 Block of BRYANT ST  17900286809024
#
#                                      location
# 0        (37.775420706711, -122.403404791479)
# 1        (37.775420706711, -122.403404791479)
# 2       (37.7299809672996, -122.388856204292)
# 3       (37.7857883766888, -122.412970537591)
# 4       (37.7650501214668, -122.419671780296)
# ...                                       ...
# 150495  (37.7714278595913, -122.453981622365)
# 150496  (37.7966261239618, -122.401857374739)
# 150497   (37.7906727649886, -122.41226909106)
# 150498  (37.7882745285785, -122.406658711008)
# 150499   (37.775420706711, -122.403404791479)
#
# [150500 rows x 9 columns]

# %%
df["location"].value_counts()
# Out:
# (37.775420706711, -122.403404791479)     3536
# (37.7564864109309, -122.406539115148)     625
# (37.7841893501425, -122.407633520742)     624
# (37.7850629421661, -122.406520987144)     513
# (37.7650501214668, -122.419671780296)     494
#                                          ...
# (37.7900661929348, -122.397091759801)       1
# (37.765562630666, -122.472365661916)        1
# (37.7788362914544, -122.445347828455)       1
# (37.7440886645957, -122.49457341502)        1
# (37.7269401048819, -122.441437353343)       1
# Name: location, Length: 19386, dtype: int64

# %%
ax = sns.countplot(x = "department_district", data=df, palette='rainbow')
ax.tick_params(axis='x', rotation=30)
plt.tight_layout()
plt.show()

# %%
df['location'].dtype
# Out:
# dtype('O')

# %%
df['location'][0]
# Out:
# '(37.775420706711, -122.403404791479)'

# %%
a=float(df['location'][10].split(",")[0][1:])

# %%
a
# Out:
# 37.7644781578695

# %%
float(df['location'][10].split(",")[1][:-1])
# Out:
# -122.477376524003

# %%
df["lat"] = df['location'].apply(lambda x : x.split(',')[0][1:])

# %%
df["long"] = df['location'].apply(lambda x : x.split(',')[1][:-1])

# %%
df = df.drop("location" , axis =1)

# %%
sns.scatterplot(x="lat", y="long", data=df)
# Out:
# <AxesSubplot:xlabel='lat', ylabel='long'>

# %%
max(df['long'])
# Out:
# ' -122.513642064265'

# %%
sns.countplot(x="crime_description",data=df)
# Out:
# <AxesSubplot:xlabel='crime_description', ylabel='count'>

# %%
df.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id               lat  \
# 0  800 Block of BRYANT ST  12005827212120   37.775420706711
# 1  800 Block of BRYANT ST  12005827212168   37.775420706711
# 2   KEITH ST / SHAFTER AV  14105926363010  37.7299809672996
# 3  JONES ST / OFARRELL ST  16001366271000  37.7857883766888
# 4    16TH ST / MISSION ST  16000274071000  37.7650501214668
#
#                  long
# 0   -122.403404791479
# 1   -122.403404791479
# 2   -122.388856204292
# 3   -122.412970537591
# 4   -122.419671780296

# %%
sns.countplot(x="crime_description",data=df)

# %%
df['crime_description'].value_counts()
# Out:
# GRAND THEFT FROM LOCKED AUTO                  17741
# LOST PROPERTY                                  4596
# AIDED CASE, MENTAL DISTURBED                   4566
# PETTY THEFT OF PROPERTY                        4416
# MALICIOUS MISCHIEF, VANDALISM                  4262
#                                               ...
# ATTEMPTED ROBBERY CHAIN STORE WITH A KNIFE        1
# PROCUREMENT, PIMPING, & PANDERING                 1
# DOG, BARKING                                      1
# TELEPHONE OR TELEGRAPH MESSAGES, ALTERING         1
# FAILURE TO REGISTER AS NARCOTICS ADDICT           1
# Name: crime_description, Length: 726, dtype: int64

# %%
df['crime_description'].value_counts()
# Out:
# LARCENY/THEFT                  40409
# OTHER OFFENSES                 19599
# NON-CRIMINAL                   17866
# ASSAULT                        13577
# VANDALISM                       8589
# VEHICLE THEFT                   6419
# WARRANTS                        5914
# BURGLARY                        5802
# SUSPICIOUS OCC                  5782
# MISSING PERSON                  4338
# DRUG/NARCOTIC                   4243
# ROBBERY                         3299
# FRAUD                           2635
# SECONDARY CODES                 1841
# TRESPASS                        1812
# WEAPON LAWS                     1658
# SEX OFFENSES, FORCIBLE           940
# STOLEN PROPERTY                  882
# RECOVERED VEHICLE                736
# DISORDERLY CONDUCT               658
# PROSTITUTION                     641
# FORGERY/COUNTERFEITING           619
# DRUNKENNESS                      465
# DRIVING UNDER THE INFLUENCE      378
# ARSON                            286
# KIDNAPPING                       257
# EMBEZZLEMENT                     168
# LIQUOR LAWS                      156
# RUNAWAY                          140
# SUICIDE                           69
# BRIBERY                           66
# EXTORTION                         60
# FAMILY OFFENSES                   53
# LOITERING                         42
# SEX OFFENSES, NON FORCIBLE        40
# BAD CHECKS                        34
# GAMBLING                          20
# PORNOGRAPHY/OBSCENE MAT            4
# TREA                               3
# Name: category, dtype: int64

# %%
df["crime_date"].value_counts()
# Out:
# 2016-01-01 00:01:00    68
# 2016-08-25 12:00:00    46
# 2016-02-04 12:00:00    42
# 2016-07-01 00:01:00    40
# 2016-09-01 12:00:00    39
#                        ..
# 2016-04-06 17:20:00     1
# 2016-09-11 14:17:00     1
# 2016-10-03 23:05:00     1
# 2016-12-07 13:24:00     1
# 2016-06-03 12:05:00     1
# Name: crime_date, Length: 67140, dtype: int64

# %%
df["crime_date"].dtype
# Out:
# dtype('O')

# %%
df['crime_date'][0][0:7]
# Out:
# '2016-01'

# %%
df['month'] = df['crime_date'].apply(lambda x:x[0:7])

# %%
df["COUNTER"] =1

# %%
df.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id               lat  \
# 0  800 Block of BRYANT ST  12005827212120   37.775420706711
# 1  800 Block of BRYANT ST  12005827212168   37.775420706711
# 2   KEITH ST / SHAFTER AV  14105926363010  37.7299809672996
# 3  JONES ST / OFARRELL ST  16001366271000  37.7857883766888
# 4    16TH ST / MISSION ST  16000274071000  37.7650501214668
#
#                  long    month  COUNTER
# 0   -122.403404791479  2016-01        1
# 1   -122.403404791479  2016-01        1
# 2   -122.388856204292  2016-04        1
# 3   -122.412970537591  2016-01        1
# 4   -122.419671780296  2016-01        1

# %%
# !pip install dataprep
# Out:
# Collecting dataprep
#   Downloading dataprep-0.4.5-py3-none-any.whl (9.9 MB)
# Collecting varname<0.9.0,>=0.8.1
#   Downloading varname-0.8.3-py3-none-any.whl (21 kB)
# Collecting numpy<2.0,>=1.21
#   Downloading numpy-1.24.1-cp38-cp38-win_amd64.whl (14.9 MB)
# Collecting jsonpath-ng<2.0,>=1.5
#   Downloading jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting flask_cors<4.0.0,>=3.0.10
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting metaphone<0.7,>=0.6
#   Downloading Metaphone-0.6.tar.gz (14 kB)
# Requirement already satisfied: tqdm<5.0,>=4.48 in c:\users\mehul\anaconda\lib\site-packages (from dataprep) (4.59.0)
# Collecting nltk<4.0.0,>=3.6.7
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting dask[array,dataframe,delayed]>=2022.3.0
#   Downloading dask-2022.12.1-py3-none-any.whl (1.1 MB)
# Collecting jinja2<3.1,>=3.0
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Requirement already satisfied: pydantic<2.0,>=1.6 in c:\users\mehul\anaconda\lib\site-packages (from dataprep) (1.8.2)
# Collecting flask<3,>=2
#   Downloading Flask-2.2.2-py3-none-any.whl (101 kB)
# Requirement already satisfied: pandas<2.0,>=1.1 in c:\users\mehul\anaconda\lib\site-packages (from dataprep) (1.2.4)
# Collecting regex<2022.0.0,>=2021.8.3
#   Downloading regex-2021.11.10-cp38-cp38-win_amd64.whl (273 kB)
# Requirement already satisfied: ipywidgets<8.0,>=7.5 in c:\users\mehul\anaconda\lib\site-packages (from dataprep) (7.6.3)
# Collecting rapidfuzz<3.0.0,>=2.1.2
#   Downloading rapidfuzz-2.13.7-cp38-cp38-win_amd64.whl (1.0 MB)
# Collecting sqlalchemy==1.3.24
#   Downloading SQLAlchemy-1.3.24-cp38-cp38-win_amd64.whl (1.2 MB)
# Collecting wordcloud<2.0,>=1.8
#   Downloading wordcloud-1.8.2.2-cp38-cp38-win_amd64.whl (152 kB)
# Requirement already satisfied: bokeh<3,>=2 in c:\users\mehul\anaconda\lib\site-packages (from dataprep) (2.3.2)
# Collecting aiohttp<4.0,>=3.6
#   Downloading aiohttp-3.8.3-cp38-cp38-win_amd64.whl (324 kB)
# Collecting python-crfsuite==0.9.8
#   Downloading python_crfsuite-0.9.8-cp38-cp38-win_amd64.whl (152 kB)
# Collecting pydot<2.0.0,>=1.4.2
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting python-stdnum<2.0,>=1.16
#   Downloading python_stdnum-1.18-py2.py3-none-any.whl (1.0 MB)
# Collecting scipy<2.0,>=1.8
#   Downloading scipy-1.10.0-cp38-cp38-win_amd64.whl (42.2 MB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp38-cp38-win_amd64.whl (28 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp38-cp38-win_amd64.whl (34 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp38-cp38-win_amd64.whl (56 kB)
# Collecting charset-normalizer<3.0,>=2.0
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mehul\anaconda\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (20.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\mehul\anaconda\lib\site-packages (from bokeh<3,>=2->dataprep) (3.7.4.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\mehul\anaconda\lib\site-packages (from bokeh<3,>=2->dataprep) (8.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\mehul\anaconda\lib\site-packages (from bokeh<3,>=2->dataprep) (2.8.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\mehul\anaconda\lib\site-packages (from bokeh<3,>=2->dataprep) (5.4.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\mehul\anaconda\lib\site-packages (from bokeh<3,>=2->dataprep) (6.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\mehul\anaconda\lib\site-packages (from bokeh<3,>=2->dataprep) (20.9)
# Requirement already satisfied: partd>=0.3.10 in c:\users\mehul\anaconda\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.2.0)
# Requirement already satisfied: click>=7.0 in c:\users\mehul\anaconda\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (7.1.2)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\mehul\anaconda\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.11.1)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\mehul\anaconda\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.6.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\mehul\anaconda\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.9.0)
# Collecting Werkzeug>=2.2.2
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\mehul\anaconda\lib\site-packages (from flask<3,>=2->dataprep) (3.10.0)
# Collecting click>=7.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
# Collecting itsdangerous>=2.0
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: colorama in c:\users\mehul\anaconda\lib\site-packages (from click>=7.0->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.4.4)
# Requirement already satisfied: Six in c:\users\mehul\anaconda\lib\site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\mehul\anaconda\lib\site-packages (from importlib-metadata>=3.6.0->flask<3,>=2->dataprep) (3.4.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\mehul\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\mehul\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (7.22.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\mehul\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.3.4)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\mehul\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\mehul\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\mehul\anaconda\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.0.5)
# Requirement already satisfied: jupyter-client in c:\users\mehul\anaconda\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (6.1.12)
# Requirement already satisfied: jedi>=0.16 in c:\users\mehul\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mehul\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.17)
# Requirement already satisfied: pygments in c:\users\mehul\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.8.1)
# Requirement already satisfied: pickleshare in c:\users\mehul\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\mehul\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (52.0.0.post20210125)
# Requirement already satisfied: backcall in c:\users\mehul\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: decorator in c:\users\mehul\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (5.0.6)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\mehul\anaconda\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.0)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp38-cp38-win_amd64.whl (17 kB)
# Requirement already satisfied: ply in c:\users\mehul\anaconda\lib\site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (3.11)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\mehul\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (3.2.0)
# Requirement already satisfied: ipython-genutils in c:\users\mehul\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\mehul\anaconda\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (4.7.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\mehul\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.17.3)
# Requirement already satisfied: joblib in c:\users\mehul\anaconda\lib\site-packages (from nltk<4.0.0,>=3.6.7->dataprep) (1.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\mehul\anaconda\lib\site-packages (from packaging>=16.8->bokeh<3,>=2->dataprep) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mehul\anaconda\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2021.1)
# Requirement already satisfied: locket in c:\users\mehul\anaconda\lib\site-packages\locket-0.2.1-py3.8.egg (from partd>=0.3.10->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.2.1)
# Requirement already satisfied: wcwidth in c:\users\mehul\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.5)
# Collecting pure_eval<1.0.0
#   Using cached pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting asttokens<3.0.0,>=2.0.0
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Collecting executing<0.9.0,>=0.8.3
#   Using cached executing-0.8.3-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\mehul\anaconda\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.3.0)
# Requirement already satisfied: nbconvert in c:\users\mehul\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.0.7)
# Requirement already satisfied: prometheus-client in c:\users\mehul\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.10.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\mehul\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\mehul\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\mehul\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (20.0.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\mehul\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.9.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mehul\anaconda\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (227)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\mehul\anaconda\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.7)
# Requirement already satisfied: matplotlib in c:\users\mehul\anaconda\lib\site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.3.4)
# Requirement already satisfied: idna>=2.0 in c:\users\mehul\anaconda\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->dataprep) (2.10)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\mehul\anaconda\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\mehul\anaconda\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.20)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mehul\anaconda\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mehul\anaconda\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.10.0)
# Requirement already satisfied: bleach in c:\users\mehul\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (3.3.0)
# Requirement already satisfied: defusedxml in c:\users\mehul\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\mehul\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\mehul\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\mehul\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mehul\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mehul\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: testpath in c:\users\mehul\anaconda\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.4.4)
# Requirement already satisfied: async-generator in c:\users\mehul\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\mehul\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\mehul\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# Building wheels for collected packages: metaphone
#   Building wheel for metaphone (setup.py): started
#   Building wheel for metaphone (setup.py): finished with status 'done'
#   Created wheel for metaphone: filename=Metaphone-0.6-py3-none-any.whl size=13905 sha256=5d9dc2ad855d90b899e5553984d9977ee3113e43e2be761f7e54f3206b32386c
#   Stored in directory: c:\users\mehul\appdata\local\pip\cache\wheels\ea\4e\3b\0634f08a7980461ad630fa4147cbd25913b008b4a02992ba66
# Successfully built metaphone
# Installing collected packages: MarkupSafe, jinja2, Werkzeug, numpy, multidict, itsdangerous, frozenlist, click, yarl, regex, pure-eval, flask, executing, dask, charset-normalizer, async-timeout, asttokens, aiosignal, wordcloud, varname, sqlalchemy, scipy, rapidfuzz, python-stdnum, python-crfsuite, pydot, nltk, metaphone, jsonpath-ng, flask-cors, aiohttp, dataprep
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\mehul\\anaconda\\Lib\\site-packages\\~arkupsafe\\_speedups.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
order = df["department_district"].value_counts().index
ax = sns.countplot(x = "department_district", data=df, palette='rainbow',order=order[:8])
ax.tick_params(axis='x', rotation=30)
plt.tight_layout()
plt.show()

# %%
order = df["category"].value_counts().index
ax = sns.countplot(x = "category", data=df, palette='rainbow',order=order[:8])
ax.tick_params(axis='x', rotation=30)
plt.tight_layout()
plt.show()

# %%
order = df["resolution"].value_counts().index
ax = sns.countplot(x = "resolution", data=df, palette='rainbow',order=order[:6])
ax.tick_params(axis='x', rotation=60)
plt.tight_layout()
plt.show()

# %%
order = df["crime_description"].value_counts().index
ax = sns.countplot(x = "crime_description", data=df, palette='rainbow',order=order[:8])
ax.tick_params(axis='x', rotation=60)
plt.tight_layout()
plt.show()

# %%
order = df["address"].value_counts().index
ax = sns.countplot(x = "address", data=df, palette='rainbow',order=order[:5])
ax.tick_params(axis='x', rotation=60)
plt.tight_layout()
plt.show()

# %%
sns.set_style('darkgrid')
plt.style.use('seaborn-darkgrid')

# %%
import dask.dataframe as dd

# %%
df_2 = dd.read_csv("police_department_data.csv")

# %%
df_2.describe().compute()
# Out:
#         incident_id  department_id
# count  1.505000e+05   1.505000e+05
# mean   1.616440e+08   1.616440e+13
# std    5.535976e+06   5.535976e+11
# min    1.135121e+07   1.135121e+12
# 25%    1.603283e+08   1.603283e+13
# 50%    1.606541e+08   1.606541e+13
# 75%    1.609764e+08   1.609764e+13
# max    9.910090e+08   9.910090e+13

# %%
df_2['month'] = df_2['crime_date'].apply(lambda x:x[0:7])
# Out:
# C:\Users\mehul\anaconda\lib\site-packages\dask\dataframe\core.py:3519: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('crime_date', 'object'))
#
#   warnings.warn(meta_warning(meta))

# %%
df_2["COUNTER"] =1

# %%
df.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id               lat  \
# 0  800 Block of BRYANT ST  12005827212120   37.775420706711
# 1  800 Block of BRYANT ST  12005827212168   37.775420706711
# 2   KEITH ST / SHAFTER AV  14105926363010  37.7299809672996
# 3  JONES ST / OFARRELL ST  16001366271000  37.7857883766888
# 4    16TH ST / MISSION ST  16000274071000  37.7650501214668
#
#                  long    month  COUNTER
# 0   -122.403404791479  2016-01        1
# 1   -122.403404791479  2016-01        1
# 2   -122.388856204292  2016-04        1
# 3   -122.412970537591  2016-01        1
# 4   -122.419671780296  2016-01        1

# %%
df["crime_date"][5250]
# Out:
# '2016-03-15 16:15:00'

# %%
df["crime_date"][5250][11:13]
# Out:
# '16'

# %%
df['hour'].value_counts()
# Out:
# 18    9718
# 17    9559
# 12    9021
# 19    8981
# 16    8656
# 15    8329
# 20    8098
# 14    7621
# 21    7480
# 13    7268
# 22    7099
# 00    6941
# 11    6786
# 23    6573
# 10    6483
# 09    5865
# 08    5575
# 01    4359
# 07    3894
# 02    3494
# 03    2553
# 06    2518
# 04    1885
# 05    1744
# Name: hour, dtype: int64

# %%
df_2['hour'] = df_2['crime_date'].apply(lambda x:x[11:13])
# Out:
# C:\Users\mehul\anaconda\lib\site-packages\dask\dataframe\core.py:3519: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=('crime_date', 'object'))
#
#   warnings.warn(meta_warning(meta))

# %%
plt.figure(figsize=(18,5))
df_2.groupby('month').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by Year and Month")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by Year and Month')

# %%
plt.figure(figsize=(18,6))
df_2.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour')

# %%
df_crime = df_2[df_2["crime_description"]=="STOLEN AUTOMOBILE"]

# %%
plt.figure(figsize=(18,6))
df_crime.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases of STOLEN AUTOMOBILE")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases of STOLEN AUTOMOBILE')

# %%
df_Locked_auto = df_2[df_2["crime_description"]=="GRAND THEFT FROM LOCKED AUTO"]

# %%
df_Lost_property = df_2[df_2["crime_description"]=="LOST PROPERTY"]

# %%
df_crime = df_2[df_2["crime_description"]=="STOLEN AUTOMOBILE"]

# %%
plt.figure(figsize=(18,6))
df_Locked_auto.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases of GRAND THEFT FROM LOCKED AUTO")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases of GRAND THEFT FROM LOCKED AUTO')

# %%
plt.figure(figsize=(18,6))
df_Lost_property.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases of LOST PROPERTY")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases of LOST PROPERTY')

# %%
df.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id               lat  \
# 0  800 Block of BRYANT ST  12005827212120   37.775420706711
# 1  800 Block of BRYANT ST  12005827212168   37.775420706711
# 2   KEITH ST / SHAFTER AV  14105926363010  37.7299809672996
# 3  JONES ST / OFARRELL ST  16001366271000  37.7857883766888
# 4    16TH ST / MISSION ST  16000274071000  37.7650501214668
#
#                  long    month  COUNTER hour
# 0   -122.403404791479  2016-01        1   11
# 1   -122.403404791479  2016-01        1   11
# 2   -122.388856204292  2016-04        1   14
# 3   -122.412970537591  2016-01        1   23
# 4   -122.419671780296  2016-01        1   00

# %%
df["address"].value_counts()
# Out:
# 800 Block of BRYANT ST          3561
# 800 Block of MARKET ST          1405
# 1000 Block of POTRERO AV         644
# 900 Block of MARKET ST           547
# 0 Block of UNITEDNATIONS PZ      452
#                                 ...
# 900 Block of DARIEN WY             1
# 200 Block of CAROLINA ST           1
# OCEAN AV / HAROLD AV               1
# MISSISSIPPI ST / MARIPOSA ST       1
# MENDELL ST / FAIRFAX AV            1
# Name: address, Length: 16130, dtype: int64

# %%
df_bryant = df_2[df_2["address"] == "800 Block of BRYANT ST"]

# %%
df_market = df_2[df_2["address"] == "800 Block of MARKET ST"]

# %%
df_potrero = df_2[df_2["address"] == "1000 Block of POTRERO AV"]

# %%
plt.figure(figsize=(18,6))
df_bryant.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases at 800 Block of BRYANT ST ")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases at 800 Block of BRYANT ST ')

# %%
plt.figure(figsize=(18,6))
df_market.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases at 800 Block of MARKET ST ")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases at 800 Block of MARKET ST ')

# %%
plt.figure(figsize=(18,6))
df_potrero.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases at 1000 Block of POTRERO AV ")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases at 1000 Block of POTRERO AV ')

# %%
df.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id               lat  \
# 0  800 Block of BRYANT ST  12005827212120   37.775420706711
# 1  800 Block of BRYANT ST  12005827212168   37.775420706711
# 2   KEITH ST / SHAFTER AV  14105926363010  37.7299809672996
# 3  JONES ST / OFARRELL ST  16001366271000  37.7857883766888
# 4    16TH ST / MISSION ST  16000274071000  37.7650501214668
#
#                  long    month  COUNTER hour
# 0   -122.403404791479  2016-01        1   11
# 1   -122.403404791479  2016-01        1   11
# 2   -122.388856204292  2016-04        1   14
# 3   -122.412970537591  2016-01        1   23
# 4   -122.419671780296  2016-01        1   00

# %%
df["category"].value_counts()
# Out:
# LARCENY/THEFT                  40409
# OTHER OFFENSES                 19599
# NON-CRIMINAL                   17866
# ASSAULT                        13577
# VANDALISM                       8589
# VEHICLE THEFT                   6419
# WARRANTS                        5914
# BURGLARY                        5802
# SUSPICIOUS OCC                  5782
# MISSING PERSON                  4338
# DRUG/NARCOTIC                   4243
# ROBBERY                         3299
# FRAUD                           2635
# SECONDARY CODES                 1841
# TRESPASS                        1812
# WEAPON LAWS                     1658
# SEX OFFENSES, FORCIBLE           940
# STOLEN PROPERTY                  882
# RECOVERED VEHICLE                736
# DISORDERLY CONDUCT               658
# PROSTITUTION                     641
# FORGERY/COUNTERFEITING           619
# DRUNKENNESS                      465
# DRIVING UNDER THE INFLUENCE      378
# ARSON                            286
# KIDNAPPING                       257
# EMBEZZLEMENT                     168
# LIQUOR LAWS                      156
# RUNAWAY                          140
# SUICIDE                           69
# BRIBERY                           66
# EXTORTION                         60
# FAMILY OFFENSES                   53
# LOITERING                         42
# SEX OFFENSES, NON FORCIBLE        40
# BAD CHECKS                        34
# GAMBLING                          20
# PORNOGRAPHY/OBSCENE MAT            4
# TREA                               3
# Name: category, dtype: int64

# %%
df_weapon = df[df["category"] == "WEAPON LAWS"]

# %%
order = df_weapon["department_district"].value_counts().index
ax = sns.countplot(x = "department_district", data=df_weapon, palette='rainbow',order=order[:5])
ax.tick_params(axis='x', rotation=60)
plt.tight_layout()
plt.title("CASES OF WEAPON LAWS BY DEPARTMENT")
plt.show()

# %%
order = df_weapon["address"].value_counts().index
ax = sns.countplot(x = "address", data=df_weapon, palette='rainbow',order=order[:5])
ax.tick_params(axis='x', rotation=60)
plt.tight_layout()
plt.title("CASES OF WEAPON LAWS BY DEPARTMENT")
plt.show()

# %%
plt.figure(figsize=(18,6))
df_weapon.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases WEAPON LAWS ")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases WEAPON LAWS ')

# %%
df_burglary = df_2[df_2["category"]=="BURGLARY"]

# %%
plt.figure(figsize=(18,6))
df_burglary.groupby('hour').count().compute()['COUNTER'].plot.line(marker='o')
plt.title("Total Number of Reports by hour for cases BURGLARY ")
# Out:
# Text(0.5, 1.0, 'Total Number of Reports by hour for cases BURGLARY ')

# %%
df_burglary["department_district"].value_counts().compute()
# Out:
# SOUTHERN      842
# NORTHERN      803
# MISSION       793
# TARAVAL       695
# CENTRAL       645
# INGLESIDE     534
# BAYVIEW       521
# PARK          413
# RICHMOND      395
# TENDERLOIN    161
# Name: department_district, dtype: int64
